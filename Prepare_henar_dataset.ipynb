# %% [markdown]
# ## Este script sirve para cortar imágenes en n partes y contabilizarlas

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.utils import load_img

import os
import seaborn as sns
from matplotlib import pyplot as plt

from fnmatch import fnmatch

# %%
def count_files(directory, search_string):    
    count = 0
    for file in os.listdir(directory):
        if fnmatch(file, "*" + search_string + "*"):
            count += 1
    return count

# %%
def crop_directory_subdirectory(path, n_horizontal, n_vertical):

    #This function takes a "root" directory and crops all the images in all the subdirectories, crops it in n_pieces, and then removes the ooriginal image

    for subdir, dirs, files in os.walk(path):
        for file in files:       
            
            f = os.path.join(subdir, file)
            im = tf.keras.utils.load_img(f)
            
            imgwidth, imgheight = im.size
            

            trozos_h = int(imgwidth/n_horizontal)
            trozos_v = int(imgheight/n_vertical)
            
            

            for i in range(n_horizontal):
                for j in range(n_vertical):
                    
                    print(f)

                    # print("i = ", i)
                    # print("j = ", j)
                    #print( trozos_v*j ,trozos_h*i ,trozos_v*j + trozos_v,trozos_h*i+ trozos_h)        
                        
                    trozo = im.crop((trozos_h*j ,trozos_v*i ,trozos_h*j + trozos_h,trozos_v*i+ trozos_v))    
                    

                    trozo.save(f + str(i) + "_" + str(j)+ ".jpg")


            os.remove(f)

# %%
directorio_cortar="private_dataset_new"

crop_directory_subdirectory('private_dataset_new',2,2)
# Out:
# private_dataset_new\aca_h\j abd 20x 15.jpg
# private_dataset_new\aca_h\j abd 20x 15.jpg
# private_dataset_new\aca_h\j abd 20x 15.jpg
# private_dataset_new\aca_h\j abd 20x 15.jpg
# private_dataset_new\aca_h\j abd 20x 19 .jpg
# private_dataset_new\aca_h\j abd 20x 19 .jpg
# private_dataset_new\aca_h\j abd 20x 19 .jpg
# private_dataset_new\aca_h\j abd 20x 19 .jpg
# private_dataset_new\aca_h\j abd 20x 20.jpg
# private_dataset_new\aca_h\j abd 20x 20.jpg
# private_dataset_new\aca_h\j abd 20x 20.jpg
# private_dataset_new\aca_h\j abd 20x 20.jpg
# private_dataset_new\aca_h\j abd 20x 22.jpg
# private_dataset_new\aca_h\j abd 20x 22.jpg
# private_dataset_new\aca_h\j abd 20x 22.jpg
# private_dataset_new\aca_h\j abd 20x 22.jpg
# private_dataset_new\aca_h\j abd 20x 23.jpg
# private_dataset_new\aca_h\j abd 20x 23.jpg
# private_dataset_new\aca_h\j abd 20x 23.jpg
# private_dataset_new\aca_h\j abd 20x 23.jpg
# private_dataset_new\aca_h\j abd 20x 24.jpg
# private_dataset_new\aca_h\j abd 20x 24.jpg
# private_dataset_new\aca_h\j abd 20x 24.jpg
# private_dataset_new\aca_h\j abd 20x 24.jpg
# private_dataset_new\aca_h\j abd 20x 25.jpg
# private_dataset_new\aca_h\j abd 20x 25.jpg
# private_dataset_new\aca_h\j abd 20x 25.jpg
# private_dataset_new\aca_h\j abd 20x 25.jpg
# private_dataset_new\aca_h\j abd 20x 31.jpg
# private_dataset_new\aca_h\j abd 20x 31.jpg
# private_dataset_new\aca_h\j abd 20x 31.jpg
# private_dataset_new\aca_h\j abd 20x 31.jpg
# private_dataset_new\aca_h\j abd 20x 32.jpg
# private_dataset_new\aca_h\j abd 20x 32.jpg
# private_dataset_new\aca_h\j abd 20x 32.jpg
# private_dataset_new\aca_h\j abd 20x 32.jpg
# private_dataset_new\aca_h\j abd 20x 33.jpg
# private_dataset_new\aca_h\j abd 20x 33.jpg
# private_dataset_new\aca_h\j abd 20x 33.jpg
# private_dataset_new\aca_h\j abd 20x 33.jpg
# private_dataset_new\aca_h\j abd 20x 34.jpg
# private_dataset_new\aca_h\j abd 20x 34.jpg
# private_dataset_new\aca_h\j abd 20x 34.jpg
# private_dataset_new\aca_h\j abd 20x 34.jpg
# private_dataset_new\aca_h\j abd 20x 38.jpg
# private_dataset_new\aca_h\j abd 20x 38.jpg
# private_dataset_new\aca_h\j abd 20x 38.jpg
# private_dataset_new\aca_h\j abd 20x 38.jpg
# private_dataset_new\aca_h\j abd 20x 39.jpg
# private_dataset_new\aca_h\j abd 20x 39.jpg
# private_dataset_new\aca_h\j abd 20x 39.jpg
# private_dataset_new\aca_h\j abd 20x 39.jpg
# private_dataset_new\aca_h\j abd 20x 40.jpg
# private_dataset_new\aca_h\j abd 20x 40.jpg
# private_dataset_new\aca_h\j abd 20x 40.jpg
# private_dataset_new\aca_h\j abd 20x 40.jpg
# private_dataset_new\aca_h\j abd 20x1.jpg
# private_dataset_new\aca_h\j abd 20x1.jpg
# private_dataset_new\aca_h\j abd 20x1.jpg
# private_dataset_new\aca_h\j abd 20x1.jpg
# private_dataset_new\aca_h\j abd 20x14.jpg
# private_dataset_new\aca_h\j abd 20x14.jpg
# private_dataset_new\aca_h\j abd 20x14.jpg
# private_dataset_new\aca_h\j abd 20x14.jpg
# private_dataset_new\aca_h\j abd 20x16.jpg
# private_dataset_new\aca_h\j abd 20x16.jpg
# private_dataset_new\aca_h\j abd 20x16.jpg
# private_dataset_new\aca_h\j abd 20x16.jpg
# private_dataset_new\aca_h\j abd 20x17.jpg
# private_dataset_new\aca_h\j abd 20x17.jpg
# private_dataset_new\aca_h\j abd 20x17.jpg
# private_dataset_new\aca_h\j abd 20x17.jpg
# private_dataset_new\aca_h\j abd 20x18.jpg
# private_dataset_new\aca_h\j abd 20x18.jpg
# private_dataset_new\aca_h\j abd 20x18.jpg
# private_dataset_new\aca_h\j abd 20x18.jpg
# private_dataset_new\aca_h\j abd 20x2.jpg
# private_dataset_new\aca_h\j abd 20x2.jpg
# private_dataset_new\aca_h\j abd 20x2.jpg
# private_dataset_new\aca_h\j abd 20x2.jpg
# private_dataset_new\aca_h\j abd 20x29.jpg
# private_dataset_new\aca_h\j abd 20x29.jpg
# private_dataset_new\aca_h\j abd 20x29.jpg
# private_dataset_new\aca_h\j abd 20x29.jpg
# private_dataset_new\aca_h\j abd 20x3.jpg
# private_dataset_new\aca_h\j abd 20x3.jpg
# private_dataset_new\aca_h\j abd 20x3.jpg
# private_dataset_new\aca_h\j abd 20x3.jpg
# private_dataset_new\aca_h\j abd 20x4.jpg
# private_dataset_new\aca_h\j abd 20x4.jpg
# private_dataset_new\aca_h\j abd 20x4.jpg
# private_dataset_new\aca_h\j abd 20x4.jpg
# private_dataset_new\aca_h\j abd 40x 17.jpg
# private_dataset_new\aca_h\j abd 40x 17.jpg
# private_dataset_new\aca_h\j abd 40x 17.jpg
# private_dataset_new\aca_h\j abd 40x 17.jpg
# private_dataset_new\aca_h\j abd 40x 19x.jpg
# private_dataset_new\aca_h\j abd 40x 19x.jpg
# private_dataset_new\aca_h\j abd 40x 19x.jpg
# private_dataset_new\aca_h\j abd 40x 19x.jpg
# private_dataset_new\aca_h\j abd 40x11.jpg
# private_dataset_new\aca_h\j abd 40x11.jpg
# private_dataset_new\aca_h\j abd 40x11.jpg
# private_dataset_new\aca_h\j abd 40x11.jpg
# private_dataset_new\aca_h\j abd 40x12.jpg
# private_dataset_new\aca_h\j abd 40x12.jpg
# private_dataset_new\aca_h\j abd 40x12.jpg
# private_dataset_new\aca_h\j abd 40x12.jpg
# private_dataset_new\aca_h\j abd 40x14.jpg
# private_dataset_new\aca_h\j abd 40x14.jpg
# private_dataset_new\aca_h\j abd 40x14.jpg
# private_dataset_new\aca_h\j abd 40x14.jpg
# private_dataset_new\aca_h\j abd 40x18.jpg
# private_dataset_new\aca_h\j abd 40x18.jpg
# private_dataset_new\aca_h\j abd 40x18.jpg
# private_dataset_new\aca_h\j abd 40x18.jpg
# private_dataset_new\aca_h\j abd 40x20.jpg
# private_dataset_new\aca_h\j abd 40x20.jpg
# private_dataset_new\aca_h\j abd 40x20.jpg
# private_dataset_new\aca_h\j abd 40x20.jpg
# private_dataset_new\aca_h\j abd20x 21.jpg
# private_dataset_new\aca_h\j abd20x 21.jpg
# private_dataset_new\aca_h\j abd20x 21.jpg
# private_dataset_new\aca_h\j abd20x 21.jpg
# private_dataset_new\aca_h\j abd20x 26.jpg
# private_dataset_new\aca_h\j abd20x 26.jpg
# private_dataset_new\aca_h\j abd20x 26.jpg
# private_dataset_new\aca_h\j abd20x 26.jpg
# private_dataset_new\aca_h\j abd20x 27.jpg
# private_dataset_new\aca_h\j abd20x 27.jpg
# private_dataset_new\aca_h\j abd20x 27.jpg
# private_dataset_new\aca_h\j abd20x 27.jpg
# private_dataset_new\aca_h\j abd20x 35.jpg
# private_dataset_new\aca_h\j abd20x 35.jpg
# private_dataset_new\aca_h\j abd20x 35.jpg
# private_dataset_new\aca_h\j abd20x 35.jpg
# private_dataset_new\aca_h\j abd20x 37.jpg
# private_dataset_new\aca_h\j abd20x 37.jpg
# private_dataset_new\aca_h\j abd20x 37.jpg
# private_dataset_new\aca_h\j abd20x 37.jpg
# private_dataset_new\aca_h\j abd40x 15.jpg
# private_dataset_new\aca_h\j abd40x 15.jpg
# private_dataset_new\aca_h\j abd40x 15.jpg
# private_dataset_new\aca_h\j abd40x 15.jpg
# private_dataset_new\aca_h\j abd40x13.jpg
# private_dataset_new\aca_h\j abd40x13.jpg
# private_dataset_new\aca_h\j abd40x13.jpg
# private_dataset_new\aca_h\j abd40x13.jpg
# private_dataset_new\aca_h\j amd  20x 17.jpg
# private_dataset_new\aca_h\j amd  20x 17.jpg
# private_dataset_new\aca_h\j amd  20x 17.jpg
# private_dataset_new\aca_h\j amd  20x 17.jpg
# private_dataset_new\aca_h\j amd 20x 15.jpg
# private_dataset_new\aca_h\j amd 20x 15.jpg
# private_dataset_new\aca_h\j amd 20x 15.jpg
# private_dataset_new\aca_h\j amd 20x 15.jpg
# private_dataset_new\aca_h\j amd 20x 16.jpg
# private_dataset_new\aca_h\j amd 20x 16.jpg
# private_dataset_new\aca_h\j amd 20x 16.jpg
# private_dataset_new\aca_h\j amd 20x 16.jpg
# private_dataset_new\aca_h\j amd 20x 18.jpg
# private_dataset_new\aca_h\j amd 20x 18.jpg
# private_dataset_new\aca_h\j amd 20x 18.jpg
# private_dataset_new\aca_h\j amd 20x 18.jpg
# private_dataset_new\aca_h\j amd 20x 19.jpg
# private_dataset_new\aca_h\j amd 20x 19.jpg
# private_dataset_new\aca_h\j amd 20x 19.jpg
# private_dataset_new\aca_h\j amd 20x 19.jpg
# private_dataset_new\aca_h\j amd 20x11.jpg
# private_dataset_new\aca_h\j amd 20x11.jpg
# private_dataset_new\aca_h\j amd 20x11.jpg
# private_dataset_new\aca_h\j amd 20x11.jpg
# private_dataset_new\aca_h\j amd 20x13.jpg
# private_dataset_new\aca_h\j amd 20x13.jpg
# private_dataset_new\aca_h\j amd 20x13.jpg
# private_dataset_new\aca_h\j amd 20x13.jpg
# private_dataset_new\aca_h\j amd 20x20.jpg
# private_dataset_new\aca_h\j amd 20x20.jpg
# private_dataset_new\aca_h\j amd 20x20.jpg
# private_dataset_new\aca_h\j amd 20x20.jpg
# private_dataset_new\aca_h\j amd 20x8.jpg
# private_dataset_new\aca_h\j amd 20x8.jpg
# private_dataset_new\aca_h\j amd 20x8.jpg
# private_dataset_new\aca_h\j amd 20x8.jpg
# private_dataset_new\aca_h\j amd 40x 1.jpg
# private_dataset_new\aca_h\j amd 40x 1.jpg
# private_dataset_new\aca_h\j amd 40x 1.jpg
# private_dataset_new\aca_h\j amd 40x 1.jpg
# private_dataset_new\aca_h\j amd20x10.jpg
# private_dataset_new\aca_h\j amd20x10.jpg
# private_dataset_new\aca_h\j amd20x10.jpg
# private_dataset_new\aca_h\j amd20x10.jpg
# private_dataset_new\aca_h\j amd20x4.jpg
# private_dataset_new\aca_h\j amd20x4.jpg
# private_dataset_new\aca_h\j amd20x4.jpg
# private_dataset_new\aca_h\j amd20x4.jpg
# private_dataset_new\aca_h\j amd20x5.jpg
# private_dataset_new\aca_h\j amd20x5.jpg
# private_dataset_new\aca_h\j amd20x5.jpg
# private_dataset_new\aca_h\j amd20x5.jpg
# private_dataset_new\aca_h\j amd20x6.jpg
# private_dataset_new\aca_h\j amd20x6.jpg
# private_dataset_new\aca_h\j amd20x6.jpg
# private_dataset_new\aca_h\j amd20x6.jpg
# private_dataset_new\aca_h\j amd20x7.jpg
# private_dataset_new\aca_h\j amd20x7.jpg
# private_dataset_new\aca_h\j amd20x7.jpg
# private_dataset_new\aca_h\j amd20x7.jpg
# private_dataset_new\aca_h\j amd20x9.jpg
# private_dataset_new\aca_h\j amd20x9.jpg
# private_dataset_new\aca_h\j amd20x9.jpg
# private_dataset_new\aca_h\j amd20x9.jpg
# private_dataset_new\aca_h\j apd 20x 12.jpg
# private_dataset_new\aca_h\j apd 20x 12.jpg
# private_dataset_new\aca_h\j apd 20x 12.jpg
# private_dataset_new\aca_h\j apd 20x 12.jpg
# private_dataset_new\aca_h\j apd 20x 13.jpg
# private_dataset_new\aca_h\j apd 20x 13.jpg
# private_dataset_new\aca_h\j apd 20x 13.jpg
# private_dataset_new\aca_h\j apd 20x 13.jpg
# private_dataset_new\aca_h\j apd 20x 20.jpg
# private_dataset_new\aca_h\j apd 20x 20.jpg
# private_dataset_new\aca_h\j apd 20x 20.jpg
# private_dataset_new\aca_h\j apd 20x 20.jpg
# private_dataset_new\aca_h\j apd 20x1.jpg
# private_dataset_new\aca_h\j apd 20x1.jpg
# private_dataset_new\aca_h\j apd 20x1.jpg
# private_dataset_new\aca_h\j apd 20x1.jpg
# private_dataset_new\aca_h\j apd 20x10.jpg
# private_dataset_new\aca_h\j apd 20x10.jpg
# private_dataset_new\aca_h\j apd 20x10.jpg
# private_dataset_new\aca_h\j apd 20x10.jpg
# private_dataset_new\aca_h\j apd 20x11.jpg
# private_dataset_new\aca_h\j apd 20x11.jpg
# private_dataset_new\aca_h\j apd 20x11.jpg
# private_dataset_new\aca_h\j apd 20x11.jpg
# private_dataset_new\aca_h\j apd 20x16.jpg
# private_dataset_new\aca_h\j apd 20x16.jpg
# private_dataset_new\aca_h\j apd 20x16.jpg
# private_dataset_new\aca_h\j apd 20x16.jpg
# private_dataset_new\aca_h\j apd 20x3.jpg
# private_dataset_new\aca_h\j apd 20x3.jpg
# private_dataset_new\aca_h\j apd 20x3.jpg
# private_dataset_new\aca_h\j apd 20x3.jpg
# private_dataset_new\aca_h\j apd 20x5.jpg
# private_dataset_new\aca_h\j apd 20x5.jpg
# private_dataset_new\aca_h\j apd 20x5.jpg
# private_dataset_new\aca_h\j apd 20x5.jpg
# private_dataset_new\aca_h\j apd 40x 19.jpg
# private_dataset_new\aca_h\j apd 40x 19.jpg
# private_dataset_new\aca_h\j apd 40x 19.jpg
# private_dataset_new\aca_h\j apd 40x 19.jpg
# private_dataset_new\aca_h\j apd20x15.jpg
# private_dataset_new\aca_h\j apd20x15.jpg
# private_dataset_new\aca_h\j apd20x15.jpg
# private_dataset_new\aca_h\j apd20x15.jpg
# private_dataset_new\aca_h\j apd20x2.jpg
# private_dataset_new\aca_h\j apd20x2.jpg
# private_dataset_new\aca_h\j apd20x2.jpg
# private_dataset_new\aca_h\j apd20x2.jpg
# private_dataset_new\aca_h\j apd20x5.jpg
# private_dataset_new\aca_h\j apd20x5.jpg
# private_dataset_new\aca_h\j apd20x5.jpg
# private_dataset_new\aca_h\j apd20x5.jpg
# private_dataset_new\aca_h\j apd20x6.jpg
# private_dataset_new\aca_h\j apd20x6.jpg
# private_dataset_new\aca_h\j apd20x6.jpg
# private_dataset_new\aca_h\j apd20x6.jpg
# private_dataset_new\aca_h\j apd20x9.jpg
# private_dataset_new\aca_h\j apd20x9.jpg
# private_dataset_new\aca_h\j apd20x9.jpg
# private_dataset_new\aca_h\j apd20x9.jpg
# private_dataset_new\aca_h\j apd40x 18.jpg
# private_dataset_new\aca_h\j apd40x 18.jpg
# private_dataset_new\aca_h\j apd40x 18.jpg
# private_dataset_new\aca_h\j apd40x 18.jpg
# private_dataset_new\aca_h\jabd 20x 30.jpg
# private_dataset_new\aca_h\jabd 20x 30.jpg
# private_dataset_new\aca_h\jabd 20x 30.jpg
# private_dataset_new\aca_h\jabd 20x 30.jpg
# private_dataset_new\aca_h\jabd 20x 5.jpg
# private_dataset_new\aca_h\jabd 20x 5.jpg
# private_dataset_new\aca_h\jabd 20x 5.jpg
# private_dataset_new\aca_h\jabd 20x 5.jpg
# private_dataset_new\aca_h\jabd 20x 7.jpg
# private_dataset_new\aca_h\jabd 20x 7.jpg
# private_dataset_new\aca_h\jabd 20x 7.jpg
# private_dataset_new\aca_h\jabd 20x 7.jpg
# private_dataset_new\aca_h\jabd 20x12.jpg
# private_dataset_new\aca_h\jabd 20x12.jpg
# private_dataset_new\aca_h\jabd 20x12.jpg
# private_dataset_new\aca_h\jabd 20x12.jpg
# private_dataset_new\aca_h\jabd 20x13.jpg
# private_dataset_new\aca_h\jabd 20x13.jpg
# private_dataset_new\aca_h\jabd 20x13.jpg
# private_dataset_new\aca_h\jabd 20x13.jpg
# private_dataset_new\aca_h\jabd20x 28.jpg
# private_dataset_new\aca_h\jabd20x 28.jpg
# private_dataset_new\aca_h\jabd20x 28.jpg
# private_dataset_new\aca_h\jabd20x 28.jpg
# private_dataset_new\aca_h\jabd20x10.jpg
# private_dataset_new\aca_h\jabd20x10.jpg
# private_dataset_new\aca_h\jabd20x10.jpg
# private_dataset_new\aca_h\jabd20x10.jpg
# private_dataset_new\aca_h\jabd20x6.jpg
# private_dataset_new\aca_h\jabd20x6.jpg
# private_dataset_new\aca_h\jabd20x6.jpg
# private_dataset_new\aca_h\jabd20x6.jpg
# private_dataset_new\aca_h\jabd20x8.jpg
# private_dataset_new\aca_h\jabd20x8.jpg
# private_dataset_new\aca_h\jabd20x8.jpg
# private_dataset_new\aca_h\jabd20x8.jpg
# private_dataset_new\aca_h\jabd20x9.jpg
# private_dataset_new\aca_h\jabd20x9.jpg
# private_dataset_new\aca_h\jabd20x9.jpg
# private_dataset_new\aca_h\jabd20x9.jpg
# private_dataset_new\aca_h\jamd 20x 12.jpg
# private_dataset_new\aca_h\jamd 20x 12.jpg
# private_dataset_new\aca_h\jamd 20x 12.jpg
# private_dataset_new\aca_h\jamd 20x 12.jpg
# private_dataset_new\aca_h\jamd20x 1.jpg
# private_dataset_new\aca_h\jamd20x 1.jpg
# private_dataset_new\aca_h\jamd20x 1.jpg
# private_dataset_new\aca_h\jamd20x 1.jpg
# private_dataset_new\aca_h\jamd20x 14.jpg
# private_dataset_new\aca_h\jamd20x 14.jpg
# private_dataset_new\aca_h\jamd20x 14.jpg
# private_dataset_new\aca_h\jamd20x 14.jpg
# private_dataset_new\aca_h\jamd20x2.jpg
# private_dataset_new\aca_h\jamd20x2.jpg
# private_dataset_new\aca_h\jamd20x2.jpg
# private_dataset_new\aca_h\jamd20x2.jpg
# private_dataset_new\aca_h\jamd20x3.jpg
# private_dataset_new\aca_h\jamd20x3.jpg
# private_dataset_new\aca_h\jamd20x3.jpg
# private_dataset_new\aca_h\jamd20x3.jpg
# private_dataset_new\aca_h\japd 20x14.jpg
# private_dataset_new\aca_h\japd 20x14.jpg
# private_dataset_new\aca_h\japd 20x14.jpg
# private_dataset_new\aca_h\japd 20x14.jpg
# private_dataset_new\aca_h\japd 40x17.jpg
# private_dataset_new\aca_h\japd 40x17.jpg
# private_dataset_new\aca_h\japd 40x17.jpg
# private_dataset_new\aca_h\japd 40x17.jpg
# private_dataset_new\aca_h\japd20x7.jpg
# private_dataset_new\aca_h\japd20x7.jpg
# private_dataset_new\aca_h\japd20x7.jpg
# private_dataset_new\aca_h\japd20x7.jpg
# private_dataset_new\aca_h\japd20x8.jpg
# private_dataset_new\aca_h\japd20x8.jpg
# private_dataset_new\aca_h\japd20x8.jpg
# private_dataset_new\aca_h\japd20x8.jpg
# private_dataset_new\nor_h\j n 20x 1.jpg
# private_dataset_new\nor_h\j n 20x 1.jpg
# private_dataset_new\nor_h\j n 20x 1.jpg
# private_dataset_new\nor_h\j n 20x 1.jpg
# private_dataset_new\nor_h\j n 20x 10.jpg
# private_dataset_new\nor_h\j n 20x 10.jpg
# private_dataset_new\nor_h\j n 20x 10.jpg
# private_dataset_new\nor_h\j n 20x 10.jpg
# private_dataset_new\nor_h\j n 20x 2.jpg
# private_dataset_new\nor_h\j n 20x 2.jpg
# private_dataset_new\nor_h\j n 20x 2.jpg
# private_dataset_new\nor_h\j n 20x 2.jpg
# private_dataset_new\nor_h\j n 20x 3.jpg
# private_dataset_new\nor_h\j n 20x 3.jpg
# private_dataset_new\nor_h\j n 20x 3.jpg
# private_dataset_new\nor_h\j n 20x 3.jpg
# private_dataset_new\nor_h\j n 20x 4.jpg
# private_dataset_new\nor_h\j n 20x 4.jpg
# private_dataset_new\nor_h\j n 20x 4.jpg
# private_dataset_new\nor_h\j n 20x 4.jpg
# private_dataset_new\nor_h\j n 20x 6.jpg
# private_dataset_new\nor_h\j n 20x 6.jpg
# private_dataset_new\nor_h\j n 20x 6.jpg
# private_dataset_new\nor_h\j n 20x 6.jpg
# private_dataset_new\nor_h\j n 20x 7.jpg
# private_dataset_new\nor_h\j n 20x 7.jpg
# private_dataset_new\nor_h\j n 20x 7.jpg
# private_dataset_new\nor_h\j n 20x 7.jpg
# private_dataset_new\nor_h\j n 20x 8.jpg
# private_dataset_new\nor_h\j n 20x 8.jpg
# private_dataset_new\nor_h\j n 20x 8.jpg
# private_dataset_new\nor_h\j n 20x 8.jpg
# private_dataset_new\nor_h\j n 20x 9.jpg
# private_dataset_new\nor_h\j n 20x 9.jpg
# private_dataset_new\nor_h\j n 20x 9.jpg
# private_dataset_new\nor_h\j n 20x 9.jpg
# private_dataset_new\nor_h\j n 40x 1.jpg
# private_dataset_new\nor_h\j n 40x 1.jpg
# private_dataset_new\nor_h\j n 40x 1.jpg
# private_dataset_new\nor_h\j n 40x 1.jpg
# private_dataset_new\nor_h\j n 40x 15.jpg
# private_dataset_new\nor_h\j n 40x 15.jpg
# private_dataset_new\nor_h\j n 40x 15.jpg
# private_dataset_new\nor_h\j n 40x 15.jpg
# private_dataset_new\nor_h\j n 40x 17.jpg
# private_dataset_new\nor_h\j n 40x 17.jpg
# private_dataset_new\nor_h\j n 40x 17.jpg
# private_dataset_new\nor_h\j n 40x 17.jpg
# private_dataset_new\nor_h\j n 40x 2.jpg
# private_dataset_new\nor_h\j n 40x 2.jpg
# private_dataset_new\nor_h\j n 40x 2.jpg
# private_dataset_new\nor_h\j n 40x 2.jpg
# private_dataset_new\nor_h\j n 40x 21.jpg
# private_dataset_new\nor_h\j n 40x 21.jpg
# private_dataset_new\nor_h\j n 40x 21.jpg
# private_dataset_new\nor_h\j n 40x 21.jpg
# private_dataset_new\nor_h\j n 40x 23.jpg
# private_dataset_new\nor_h\j n 40x 23.jpg
# private_dataset_new\nor_h\j n 40x 23.jpg
# private_dataset_new\nor_h\j n 40x 23.jpg
# private_dataset_new\nor_h\j n 40x 24.jpg
# private_dataset_new\nor_h\j n 40x 24.jpg
# private_dataset_new\nor_h\j n 40x 24.jpg
# private_dataset_new\nor_h\j n 40x 24.jpg
# private_dataset_new\nor_h\j n 40x 27.jpg
# private_dataset_new\nor_h\j n 40x 27.jpg
# private_dataset_new\nor_h\j n 40x 27.jpg
# private_dataset_new\nor_h\j n 40x 27.jpg
# private_dataset_new\nor_h\j n 40x 3.jpg
# private_dataset_new\nor_h\j n 40x 3.jpg
# private_dataset_new\nor_h\j n 40x 3.jpg
# private_dataset_new\nor_h\j n 40x 3.jpg
# private_dataset_new\nor_h\j n 40x 30.jpg
# private_dataset_new\nor_h\j n 40x 30.jpg
# private_dataset_new\nor_h\j n 40x 30.jpg
# private_dataset_new\nor_h\j n 40x 30.jpg
# private_dataset_new\nor_h\j n 40x 4.jpg
# private_dataset_new\nor_h\j n 40x 4.jpg
# private_dataset_new\nor_h\j n 40x 4.jpg
# private_dataset_new\nor_h\j n 40x 4.jpg
# private_dataset_new\nor_h\j n 40x 5.jpg
# private_dataset_new\nor_h\j n 40x 5.jpg
# private_dataset_new\nor_h\j n 40x 5.jpg
# private_dataset_new\nor_h\j n 40x 5.jpg
# private_dataset_new\nor_h\j n 40x1.jpg
# private_dataset_new\nor_h\j n 40x1.jpg
# private_dataset_new\nor_h\j n 40x1.jpg
# private_dataset_new\nor_h\j n 40x1.jpg
# private_dataset_new\nor_h\j n 40x10.jpg
# private_dataset_new\nor_h\j n 40x10.jpg
# private_dataset_new\nor_h\j n 40x10.jpg
# private_dataset_new\nor_h\j n 40x10.jpg
# private_dataset_new\nor_h\j n 40x11.jpg
# private_dataset_new\nor_h\j n 40x11.jpg
# private_dataset_new\nor_h\j n 40x11.jpg
# private_dataset_new\nor_h\j n 40x11.jpg
# private_dataset_new\nor_h\j n 40x12.jpg
# private_dataset_new\nor_h\j n 40x12.jpg
# private_dataset_new\nor_h\j n 40x12.jpg
# private_dataset_new\nor_h\j n 40x12.jpg
# private_dataset_new\nor_h\j n 40x13.jpg
# private_dataset_new\nor_h\j n 40x13.jpg
# private_dataset_new\nor_h\j n 40x13.jpg
# private_dataset_new\nor_h\j n 40x13.jpg
# private_dataset_new\nor_h\j n 40x14.jpg
# private_dataset_new\nor_h\j n 40x14.jpg
# private_dataset_new\nor_h\j n 40x14.jpg
# private_dataset_new\nor_h\j n 40x14.jpg
# private_dataset_new\nor_h\j n 40x16.jpg
# private_dataset_new\nor_h\j n 40x16.jpg
# private_dataset_new\nor_h\j n 40x16.jpg
# private_dataset_new\nor_h\j n 40x16.jpg
# private_dataset_new\nor_h\j n 40x18.jpg
# private_dataset_new\nor_h\j n 40x18.jpg
# private_dataset_new\nor_h\j n 40x18.jpg
# private_dataset_new\nor_h\j n 40x18.jpg
# private_dataset_new\nor_h\j n 40x19.jpg
# private_dataset_new\nor_h\j n 40x19.jpg
# private_dataset_new\nor_h\j n 40x19.jpg
# private_dataset_new\nor_h\j n 40x19.jpg
# private_dataset_new\nor_h\j n 40x20.jpg
# private_dataset_new\nor_h\j n 40x20.jpg
# private_dataset_new\nor_h\j n 40x20.jpg
# private_dataset_new\nor_h\j n 40x20.jpg
# private_dataset_new\nor_h\j n 40x22.jpg
# private_dataset_new\nor_h\j n 40x22.jpg
# private_dataset_new\nor_h\j n 40x22.jpg
# private_dataset_new\nor_h\j n 40x22.jpg
# private_dataset_new\nor_h\j n 40x25.jpg
# private_dataset_new\nor_h\j n 40x25.jpg
# private_dataset_new\nor_h\j n 40x25.jpg
# private_dataset_new\nor_h\j n 40x25.jpg
# private_dataset_new\nor_h\j n 40x26.jpg
# private_dataset_new\nor_h\j n 40x26.jpg
# private_dataset_new\nor_h\j n 40x26.jpg
# private_dataset_new\nor_h\j n 40x26.jpg
# private_dataset_new\nor_h\j n 40x28.jpg
# private_dataset_new\nor_h\j n 40x28.jpg
# private_dataset_new\nor_h\j n 40x28.jpg
# private_dataset_new\nor_h\j n 40x28.jpg
# private_dataset_new\nor_h\j n 40x29.jpg
# private_dataset_new\nor_h\j n 40x29.jpg
# private_dataset_new\nor_h\j n 40x29.jpg
# private_dataset_new\nor_h\j n 40x29.jpg
# private_dataset_new\nor_h\j n 40x4.jpg
# private_dataset_new\nor_h\j n 40x4.jpg
# private_dataset_new\nor_h\j n 40x4.jpg
# private_dataset_new\nor_h\j n 40x4.jpg
# private_dataset_new\nor_h\j n 40x5.jpg
# private_dataset_new\nor_h\j n 40x5.jpg
# private_dataset_new\nor_h\j n 40x5.jpg
# private_dataset_new\nor_h\j n 40x5.jpg
# private_dataset_new\nor_h\j n 40x6.jpg
# private_dataset_new\nor_h\j n 40x6.jpg
# private_dataset_new\nor_h\j n 40x6.jpg
# private_dataset_new\nor_h\j n 40x6.jpg
# private_dataset_new\nor_h\j n 40x7.jpg
# private_dataset_new\nor_h\j n 40x7.jpg
# private_dataset_new\nor_h\j n 40x7.jpg
# private_dataset_new\nor_h\j n 40x7.jpg
# private_dataset_new\nor_h\j n 40x8.jpg
# private_dataset_new\nor_h\j n 40x8.jpg
# private_dataset_new\nor_h\j n 40x8.jpg
# private_dataset_new\nor_h\j n 40x8.jpg
# private_dataset_new\nor_h\j n 40x9.jpg
# private_dataset_new\nor_h\j n 40x9.jpg
# private_dataset_new\nor_h\j n 40x9.jpg
# private_dataset_new\nor_h\j n 40x9.jpg
# private_dataset_new\nor_h\j n20x 5.jpg
# private_dataset_new\nor_h\j n20x 5.jpg
# private_dataset_new\nor_h\j n20x 5.jpg
# private_dataset_new\nor_h\j n20x 5.jpg
# private_dataset_new\nor_h\j n40x2.jpg
# private_dataset_new\nor_h\j n40x2.jpg
# private_dataset_new\nor_h\j n40x2.jpg
# private_dataset_new\nor_h\j n40x2.jpg
# private_dataset_new\nor_h\j n40x3.jpg
# private_dataset_new\nor_h\j n40x3.jpg
# private_dataset_new\nor_h\j n40x3.jpg
# private_dataset_new\nor_h\j n40x3.jpg
# private_dataset_new\nor_h\j no 10x 13.jpg
# private_dataset_new\nor_h\j no 10x 13.jpg
# private_dataset_new\nor_h\j no 10x 13.jpg
# private_dataset_new\nor_h\j no 10x 13.jpg
# private_dataset_new\nor_h\j no 10x 61.jpg
# private_dataset_new\nor_h\j no 10x 61.jpg
# private_dataset_new\nor_h\j no 10x 61.jpg
# private_dataset_new\nor_h\j no 10x 61.jpg
# private_dataset_new\nor_h\j no 10x 69.jpg
# private_dataset_new\nor_h\j no 10x 69.jpg
# private_dataset_new\nor_h\j no 10x 69.jpg
# private_dataset_new\nor_h\j no 10x 69.jpg
# private_dataset_new\nor_h\j no 20x 13.jpg
# private_dataset_new\nor_h\j no 20x 13.jpg
# private_dataset_new\nor_h\j no 20x 13.jpg
# private_dataset_new\nor_h\j no 20x 13.jpg
# private_dataset_new\nor_h\j no 20x 15.jpg
# private_dataset_new\nor_h\j no 20x 15.jpg
# private_dataset_new\nor_h\j no 20x 15.jpg
# private_dataset_new\nor_h\j no 20x 15.jpg
# private_dataset_new\nor_h\j no 20x 16.jpg
# private_dataset_new\nor_h\j no 20x 16.jpg
# private_dataset_new\nor_h\j no 20x 16.jpg
# private_dataset_new\nor_h\j no 20x 16.jpg
# private_dataset_new\nor_h\j no 20x 17.jpg
# private_dataset_new\nor_h\j no 20x 17.jpg
# private_dataset_new\nor_h\j no 20x 17.jpg
# private_dataset_new\nor_h\j no 20x 17.jpg
# private_dataset_new\nor_h\j no 20x 18.jpg
# private_dataset_new\nor_h\j no 20x 18.jpg
# private_dataset_new\nor_h\j no 20x 18.jpg
# private_dataset_new\nor_h\j no 20x 18.jpg
# private_dataset_new\nor_h\j no 20x 19.jpg
# private_dataset_new\nor_h\j no 20x 19.jpg
# private_dataset_new\nor_h\j no 20x 19.jpg
# private_dataset_new\nor_h\j no 20x 19.jpg
# private_dataset_new\nor_h\j no 20x 20.jpg
# private_dataset_new\nor_h\j no 20x 20.jpg
# private_dataset_new\nor_h\j no 20x 20.jpg
# private_dataset_new\nor_h\j no 20x 20.jpg
# private_dataset_new\nor_h\j no 20x 21.jpg
# private_dataset_new\nor_h\j no 20x 21.jpg
# private_dataset_new\nor_h\j no 20x 21.jpg
# private_dataset_new\nor_h\j no 20x 21.jpg
# private_dataset_new\nor_h\j no 20x 22.jpg
# private_dataset_new\nor_h\j no 20x 22.jpg
# private_dataset_new\nor_h\j no 20x 22.jpg
# private_dataset_new\nor_h\j no 20x 22.jpg
# private_dataset_new\nor_h\j no 20x 23.jpg
# private_dataset_new\nor_h\j no 20x 23.jpg
# private_dataset_new\nor_h\j no 20x 23.jpg
# private_dataset_new\nor_h\j no 20x 23.jpg
# private_dataset_new\nor_h\j no 20x 24.jpg
# private_dataset_new\nor_h\j no 20x 24.jpg
# private_dataset_new\nor_h\j no 20x 24.jpg
# private_dataset_new\nor_h\j no 20x 24.jpg
# private_dataset_new\nor_h\j no 20x 25.jpg
# private_dataset_new\nor_h\j no 20x 25.jpg
# private_dataset_new\nor_h\j no 20x 25.jpg
# private_dataset_new\nor_h\j no 20x 25.jpg
# private_dataset_new\nor_h\j no 20x 27.jpg
# private_dataset_new\nor_h\j no 20x 27.jpg
# private_dataset_new\nor_h\j no 20x 27.jpg
# private_dataset_new\nor_h\j no 20x 27.jpg
# private_dataset_new\nor_h\j no 20x 28.jpg
# private_dataset_new\nor_h\j no 20x 28.jpg
# private_dataset_new\nor_h\j no 20x 28.jpg
# private_dataset_new\nor_h\j no 20x 28.jpg
# private_dataset_new\nor_h\j no 20x 29.jpg
# private_dataset_new\nor_h\j no 20x 29.jpg
# private_dataset_new\nor_h\j no 20x 29.jpg
# private_dataset_new\nor_h\j no 20x 29.jpg
# private_dataset_new\nor_h\j no 20x 30.jpg
# private_dataset_new\nor_h\j no 20x 30.jpg
# private_dataset_new\nor_h\j no 20x 30.jpg
# private_dataset_new\nor_h\j no 20x 30.jpg
# private_dataset_new\nor_h\j no 20x 35.jpg
# private_dataset_new\nor_h\j no 20x 35.jpg
# private_dataset_new\nor_h\j no 20x 35.jpg
# private_dataset_new\nor_h\j no 20x 35.jpg
# private_dataset_new\nor_h\j no 20x 38.jpg
# private_dataset_new\nor_h\j no 20x 38.jpg
# private_dataset_new\nor_h\j no 20x 38.jpg
# private_dataset_new\nor_h\j no 20x 38.jpg
# private_dataset_new\nor_h\j no 20x 39.jpg
# private_dataset_new\nor_h\j no 20x 39.jpg
# private_dataset_new\nor_h\j no 20x 39.jpg
# private_dataset_new\nor_h\j no 20x 39.jpg
# private_dataset_new\nor_h\j no 20x 40.jpg
# private_dataset_new\nor_h\j no 20x 40.jpg
# private_dataset_new\nor_h\j no 20x 40.jpg
# private_dataset_new\nor_h\j no 20x 40.jpg
# private_dataset_new\nor_h\j no 20x 43.jpg
# private_dataset_new\nor_h\j no 20x 43.jpg
# private_dataset_new\nor_h\j no 20x 43.jpg
# private_dataset_new\nor_h\j no 20x 43.jpg
# private_dataset_new\nor_h\j no 20x 44.jpg
# private_dataset_new\nor_h\j no 20x 44.jpg
# private_dataset_new\nor_h\j no 20x 44.jpg
# private_dataset_new\nor_h\j no 20x 44.jpg
# private_dataset_new\nor_h\j no 20x 45.jpg
# private_dataset_new\nor_h\j no 20x 45.jpg
# private_dataset_new\nor_h\j no 20x 45.jpg
# private_dataset_new\nor_h\j no 20x 45.jpg
# private_dataset_new\nor_h\j no 20x 49.jpg
# private_dataset_new\nor_h\j no 20x 49.jpg
# private_dataset_new\nor_h\j no 20x 49.jpg
# private_dataset_new\nor_h\j no 20x 49.jpg
# private_dataset_new\nor_h\j no 20x 52.jpg
# private_dataset_new\nor_h\j no 20x 52.jpg
# private_dataset_new\nor_h\j no 20x 52.jpg
# private_dataset_new\nor_h\j no 20x 52.jpg
# private_dataset_new\nor_h\j no 20x 53.jpg
# private_dataset_new\nor_h\j no 20x 53.jpg
# private_dataset_new\nor_h\j no 20x 53.jpg
# private_dataset_new\nor_h\j no 20x 53.jpg
# private_dataset_new\nor_h\j no 20x 54.jpg
# private_dataset_new\nor_h\j no 20x 54.jpg
# private_dataset_new\nor_h\j no 20x 54.jpg
# private_dataset_new\nor_h\j no 20x 54.jpg
# private_dataset_new\nor_h\j no 20x 55.jpg
# private_dataset_new\nor_h\j no 20x 55.jpg
# private_dataset_new\nor_h\j no 20x 55.jpg
# private_dataset_new\nor_h\j no 20x 55.jpg
# private_dataset_new\nor_h\j no 20x 56.jpg
# private_dataset_new\nor_h\j no 20x 56.jpg
# private_dataset_new\nor_h\j no 20x 56.jpg
# private_dataset_new\nor_h\j no 20x 56.jpg
# private_dataset_new\nor_h\j no 20x 57.jpg
# private_dataset_new\nor_h\j no 20x 57.jpg
# private_dataset_new\nor_h\j no 20x 57.jpg
# private_dataset_new\nor_h\j no 20x 57.jpg
# private_dataset_new\nor_h\j no 20x 58.jpg
# private_dataset_new\nor_h\j no 20x 58.jpg
# private_dataset_new\nor_h\j no 20x 58.jpg
# private_dataset_new\nor_h\j no 20x 58.jpg
# private_dataset_new\nor_h\j no 20x 60.jpg
# private_dataset_new\nor_h\j no 20x 60.jpg
# private_dataset_new\nor_h\j no 20x 60.jpg
# private_dataset_new\nor_h\j no 20x 60.jpg
# private_dataset_new\nor_h\j no 20x 61.jpg
# private_dataset_new\nor_h\j no 20x 61.jpg
# private_dataset_new\nor_h\j no 20x 61.jpg
# private_dataset_new\nor_h\j no 20x 61.jpg
# private_dataset_new\nor_h\j no 20x 63.jpg
# private_dataset_new\nor_h\j no 20x 63.jpg
# private_dataset_new\nor_h\j no 20x 63.jpg
# private_dataset_new\nor_h\j no 20x 63.jpg
# private_dataset_new\nor_h\j no 20x 64.jpg
# private_dataset_new\nor_h\j no 20x 64.jpg
# private_dataset_new\nor_h\j no 20x 64.jpg
# private_dataset_new\nor_h\j no 20x 64.jpg
# private_dataset_new\nor_h\j no 20x 65.jpg
# private_dataset_new\nor_h\j no 20x 65.jpg
# private_dataset_new\nor_h\j no 20x 65.jpg
# private_dataset_new\nor_h\j no 20x 65.jpg
# private_dataset_new\nor_h\j no 20x 66.jpg
# private_dataset_new\nor_h\j no 20x 66.jpg
# private_dataset_new\nor_h\j no 20x 66.jpg
# private_dataset_new\nor_h\j no 20x 66.jpg
# private_dataset_new\nor_h\j no 20x 67.jpg
# private_dataset_new\nor_h\j no 20x 67.jpg
# private_dataset_new\nor_h\j no 20x 67.jpg
# private_dataset_new\nor_h\j no 20x 67.jpg
# private_dataset_new\nor_h\j no 20x 68.jpg
# private_dataset_new\nor_h\j no 20x 68.jpg
# private_dataset_new\nor_h\j no 20x 68.jpg
# private_dataset_new\nor_h\j no 20x 68.jpg
# private_dataset_new\nor_h\j no 20x 69.jpg
# private_dataset_new\nor_h\j no 20x 69.jpg
# private_dataset_new\nor_h\j no 20x 69.jpg
# private_dataset_new\nor_h\j no 20x 69.jpg
# private_dataset_new\nor_h\j no 20x 70.jpg
# private_dataset_new\nor_h\j no 20x 70.jpg
# private_dataset_new\nor_h\j no 20x 70.jpg
# private_dataset_new\nor_h\j no 20x 70.jpg
# private_dataset_new\nor_h\j no 20x 71.jpg
# private_dataset_new\nor_h\j no 20x 71.jpg
# private_dataset_new\nor_h\j no 20x 71.jpg
# private_dataset_new\nor_h\j no 20x 71.jpg
# private_dataset_new\nor_h\j no 20x 72.jpg
# private_dataset_new\nor_h\j no 20x 72.jpg
# private_dataset_new\nor_h\j no 20x 72.jpg
# private_dataset_new\nor_h\j no 20x 72.jpg
# private_dataset_new\nor_h\j no 20x11.jpg
# private_dataset_new\nor_h\j no 20x11.jpg
# private_dataset_new\nor_h\j no 20x11.jpg
# private_dataset_new\nor_h\j no 20x11.jpg
# private_dataset_new\nor_h\j no 20x12.jpg
# private_dataset_new\nor_h\j no 20x12.jpg
# private_dataset_new\nor_h\j no 20x12.jpg
# private_dataset_new\nor_h\j no 20x12.jpg
# private_dataset_new\nor_h\j no 20x14.jpg
# private_dataset_new\nor_h\j no 20x14.jpg
# private_dataset_new\nor_h\j no 20x14.jpg
# private_dataset_new\nor_h\j no 20x14.jpg
# private_dataset_new\nor_h\j no 20x26.jpg
# private_dataset_new\nor_h\j no 20x26.jpg
# private_dataset_new\nor_h\j no 20x26.jpg
# private_dataset_new\nor_h\j no 20x26.jpg
# private_dataset_new\nor_h\j no 20x31.jpg
# private_dataset_new\nor_h\j no 20x31.jpg
# private_dataset_new\nor_h\j no 20x31.jpg
# private_dataset_new\nor_h\j no 20x31.jpg
# private_dataset_new\nor_h\j no 20x32.jpg
# private_dataset_new\nor_h\j no 20x32.jpg
# private_dataset_new\nor_h\j no 20x32.jpg
# private_dataset_new\nor_h\j no 20x32.jpg
# private_dataset_new\nor_h\j no 20x33.jpg
# private_dataset_new\nor_h\j no 20x33.jpg
# private_dataset_new\nor_h\j no 20x33.jpg
# private_dataset_new\nor_h\j no 20x33.jpg
# private_dataset_new\nor_h\j no 20x34.jpg
# private_dataset_new\nor_h\j no 20x34.jpg
# private_dataset_new\nor_h\j no 20x34.jpg
# private_dataset_new\nor_h\j no 20x34.jpg
# private_dataset_new\nor_h\j no 20x36.jpg
# private_dataset_new\nor_h\j no 20x36.jpg
# private_dataset_new\nor_h\j no 20x36.jpg
# private_dataset_new\nor_h\j no 20x36.jpg
# private_dataset_new\nor_h\j no 20x37.jpg
# private_dataset_new\nor_h\j no 20x37.jpg
# private_dataset_new\nor_h\j no 20x37.jpg
# private_dataset_new\nor_h\j no 20x37.jpg
# private_dataset_new\nor_h\j no 20x41.jpg
# private_dataset_new\nor_h\j no 20x41.jpg
# private_dataset_new\nor_h\j no 20x41.jpg
# private_dataset_new\nor_h\j no 20x41.jpg
# private_dataset_new\nor_h\j no 20x42.jpg
# private_dataset_new\nor_h\j no 20x42.jpg
# private_dataset_new\nor_h\j no 20x42.jpg
# private_dataset_new\nor_h\j no 20x42.jpg
# private_dataset_new\nor_h\j no 20x47.jpg
# private_dataset_new\nor_h\j no 20x47.jpg
# private_dataset_new\nor_h\j no 20x47.jpg
# private_dataset_new\nor_h\j no 20x47.jpg
# private_dataset_new\nor_h\j no 20x48.jpg
# private_dataset_new\nor_h\j no 20x48.jpg
# private_dataset_new\nor_h\j no 20x48.jpg
# private_dataset_new\nor_h\j no 20x48.jpg
# private_dataset_new\nor_h\j no 20x50.jpg
# private_dataset_new\nor_h\j no 20x50.jpg
# private_dataset_new\nor_h\j no 20x50.jpg
# private_dataset_new\nor_h\j no 20x50.jpg
# private_dataset_new\nor_h\j no 20x51.jpg
# private_dataset_new\nor_h\j no 20x51.jpg
# private_dataset_new\nor_h\j no 20x51.jpg
# private_dataset_new\nor_h\j no 20x51.jpg
# private_dataset_new\nor_h\j no 20x59.jpg
# private_dataset_new\nor_h\j no 20x59.jpg
# private_dataset_new\nor_h\j no 20x59.jpg
# private_dataset_new\nor_h\j no 20x59.jpg
# private_dataset_new\nor_h\j no 20x62.jpg
# private_dataset_new\nor_h\j no 20x62.jpg
# private_dataset_new\nor_h\j no 20x62.jpg
# private_dataset_new\nor_h\j no 20x62.jpg
# private_dataset_new\nor_h\j no20x46.jpg
# private_dataset_new\nor_h\j no20x46.jpg
# private_dataset_new\nor_h\j no20x46.jpg
# private_dataset_new\nor_h\j no20x46.jpg
# private_dataset_new\scc_h\j emd 20x 2.jpg
# private_dataset_new\scc_h\j emd 20x 2.jpg
# private_dataset_new\scc_h\j emd 20x 2.jpg
# private_dataset_new\scc_h\j emd 20x 2.jpg
# private_dataset_new\scc_h\j emd 20x1.jpg
# private_dataset_new\scc_h\j emd 20x1.jpg
# private_dataset_new\scc_h\j emd 20x1.jpg
# private_dataset_new\scc_h\j emd 20x1.jpg
# private_dataset_new\scc_h\j emd 20x4.jpg
# private_dataset_new\scc_h\j emd 20x4.jpg
# private_dataset_new\scc_h\j emd 20x4.jpg
# private_dataset_new\scc_h\j emd 20x4.jpg
# private_dataset_new\scc_h\j emd 20x51.jpg
# private_dataset_new\scc_h\j emd 20x51.jpg
# private_dataset_new\scc_h\j emd 20x51.jpg
# private_dataset_new\scc_h\j emd 20x51.jpg
# private_dataset_new\scc_h\j emd 40x1.jpg
# private_dataset_new\scc_h\j emd 40x1.jpg
# private_dataset_new\scc_h\j emd 40x1.jpg
# private_dataset_new\scc_h\j emd 40x1.jpg
# private_dataset_new\scc_h\j emd20x 13.jpg
# private_dataset_new\scc_h\j emd20x 13.jpg
# private_dataset_new\scc_h\j emd20x 13.jpg
# private_dataset_new\scc_h\j emd20x 13.jpg
# private_dataset_new\scc_h\j emd20x 8.jpg
# private_dataset_new\scc_h\j emd20x 8.jpg
# private_dataset_new\scc_h\j emd20x 8.jpg
# private_dataset_new\scc_h\j emd20x 8.jpg
# private_dataset_new\scc_h\j emd20x10.jpg
# private_dataset_new\scc_h\j emd20x10.jpg
# private_dataset_new\scc_h\j emd20x10.jpg
# private_dataset_new\scc_h\j emd20x10.jpg
# private_dataset_new\scc_h\j emd20x11.jpg
# private_dataset_new\scc_h\j emd20x11.jpg
# private_dataset_new\scc_h\j emd20x11.jpg
# private_dataset_new\scc_h\j emd20x11.jpg
# private_dataset_new\scc_h\j emd20x12.jpg
# private_dataset_new\scc_h\j emd20x12.jpg
# private_dataset_new\scc_h\j emd20x12.jpg
# private_dataset_new\scc_h\j emd20x12.jpg
# private_dataset_new\scc_h\j emd20x14.jpg
# private_dataset_new\scc_h\j emd20x14.jpg
# private_dataset_new\scc_h\j emd20x14.jpg
# private_dataset_new\scc_h\j emd20x14.jpg
# private_dataset_new\scc_h\j emd20x15.jpg
# private_dataset_new\scc_h\j emd20x15.jpg
# private_dataset_new\scc_h\j emd20x15.jpg
# private_dataset_new\scc_h\j emd20x15.jpg
# private_dataset_new\scc_h\j emd20x16.jpg
# private_dataset_new\scc_h\j emd20x16.jpg
# private_dataset_new\scc_h\j emd20x16.jpg
# private_dataset_new\scc_h\j emd20x16.jpg
# private_dataset_new\scc_h\j emd20x17.jpg
# private_dataset_new\scc_h\j emd20x17.jpg
# private_dataset_new\scc_h\j emd20x17.jpg
# private_dataset_new\scc_h\j emd20x17.jpg
# private_dataset_new\scc_h\j emd20x18.jpg
# private_dataset_new\scc_h\j emd20x18.jpg
# private_dataset_new\scc_h\j emd20x18.jpg
# private_dataset_new\scc_h\j emd20x18.jpg
# private_dataset_new\scc_h\j emd20x19.jpg
# private_dataset_new\scc_h\j emd20x19.jpg
# private_dataset_new\scc_h\j emd20x19.jpg
# private_dataset_new\scc_h\j emd20x19.jpg
# private_dataset_new\scc_h\j emd20x20.jpg
# private_dataset_new\scc_h\j emd20x20.jpg
# private_dataset_new\scc_h\j emd20x20.jpg
# private_dataset_new\scc_h\j emd20x20.jpg
# private_dataset_new\scc_h\j emd20x3.jpg
# private_dataset_new\scc_h\j emd20x3.jpg
# private_dataset_new\scc_h\j emd20x3.jpg
# private_dataset_new\scc_h\j emd20x3.jpg
# private_dataset_new\scc_h\j emd20x5.jpg
# private_dataset_new\scc_h\j emd20x5.jpg
# private_dataset_new\scc_h\j emd20x5.jpg
# private_dataset_new\scc_h\j emd20x5.jpg
# private_dataset_new\scc_h\j emd20x6.jpg
# private_dataset_new\scc_h\j emd20x6.jpg
# private_dataset_new\scc_h\j emd20x6.jpg
# private_dataset_new\scc_h\j emd20x6.jpg
# private_dataset_new\scc_h\j emd20x7.jpg
# private_dataset_new\scc_h\j emd20x7.jpg
# private_dataset_new\scc_h\j emd20x7.jpg
# private_dataset_new\scc_h\j emd20x7.jpg
# private_dataset_new\scc_h\j emd20x9.jpg
# private_dataset_new\scc_h\j emd20x9.jpg
# private_dataset_new\scc_h\j emd20x9.jpg
# private_dataset_new\scc_h\j emd20x9.jpg
# private_dataset_new\scc_h\j epd 20x 4.jpg
# private_dataset_new\scc_h\j epd 20x 4.jpg
# private_dataset_new\scc_h\j epd 20x 4.jpg
# private_dataset_new\scc_h\j epd 20x 4.jpg
# private_dataset_new\scc_h\j epd 20x10.jpg
# private_dataset_new\scc_h\j epd 20x10.jpg
# private_dataset_new\scc_h\j epd 20x10.jpg
# private_dataset_new\scc_h\j epd 20x10.jpg
# private_dataset_new\scc_h\j epd20x1.jpg
# private_dataset_new\scc_h\j epd20x1.jpg
# private_dataset_new\scc_h\j epd20x1.jpg
# private_dataset_new\scc_h\j epd20x1.jpg
# private_dataset_new\scc_h\j epd20x11.jpg
# private_dataset_new\scc_h\j epd20x11.jpg
# private_dataset_new\scc_h\j epd20x11.jpg
# private_dataset_new\scc_h\j epd20x11.jpg
# private_dataset_new\scc_h\j epd20x12.jpg
# private_dataset_new\scc_h\j epd20x12.jpg
# private_dataset_new\scc_h\j epd20x12.jpg
# private_dataset_new\scc_h\j epd20x12.jpg
# private_dataset_new\scc_h\j epd20x13.jpg
# private_dataset_new\scc_h\j epd20x13.jpg
# private_dataset_new\scc_h\j epd20x13.jpg
# private_dataset_new\scc_h\j epd20x13.jpg
# private_dataset_new\scc_h\j epd20x14.jpg
# private_dataset_new\scc_h\j epd20x14.jpg
# private_dataset_new\scc_h\j epd20x14.jpg
# private_dataset_new\scc_h\j epd20x14.jpg
# private_dataset_new\scc_h\j epd20x15.jpg
# private_dataset_new\scc_h\j epd20x15.jpg
# private_dataset_new\scc_h\j epd20x15.jpg
# private_dataset_new\scc_h\j epd20x15.jpg
# private_dataset_new\scc_h\j epd20x5.jpg
# private_dataset_new\scc_h\j epd20x5.jpg
# private_dataset_new\scc_h\j epd20x5.jpg
# private_dataset_new\scc_h\j epd20x5.jpg
# private_dataset_new\scc_h\j epd20x6.jpg
# private_dataset_new\scc_h\j epd20x6.jpg
# private_dataset_new\scc_h\j epd20x6.jpg
# private_dataset_new\scc_h\j epd20x6.jpg
# private_dataset_new\scc_h\j epd20x8.jpg
# private_dataset_new\scc_h\j epd20x8.jpg
# private_dataset_new\scc_h\j epd20x8.jpg
# private_dataset_new\scc_h\j epd20x8.jpg
# private_dataset_new\scc_h\j epd20x9.jpg
# private_dataset_new\scc_h\j epd20x9.jpg
# private_dataset_new\scc_h\j epd20x9.jpg
# private_dataset_new\scc_h\j epd20x9.jpg
# private_dataset_new\scc_h\j es pd 20x 7.jpg
# private_dataset_new\scc_h\j es pd 20x 7.jpg
# private_dataset_new\scc_h\j es pd 20x 7.jpg
# private_dataset_new\scc_h\j es pd 20x 7.jpg
# private_dataset_new\scc_h\j esb40x40.jpg
# private_dataset_new\scc_h\j esb40x40.jpg
# private_dataset_new\scc_h\j esb40x40.jpg
# private_dataset_new\scc_h\j esb40x40.jpg
# private_dataset_new\scc_h\j esbd 20x48.jpg
# private_dataset_new\scc_h\j esbd 20x48.jpg
# private_dataset_new\scc_h\j esbd 20x48.jpg
# private_dataset_new\scc_h\j esbd 20x48.jpg
# private_dataset_new\scc_h\j esbd20x 34.jpg
# private_dataset_new\scc_h\j esbd20x 34.jpg
# private_dataset_new\scc_h\j esbd20x 34.jpg
# private_dataset_new\scc_h\j esbd20x 34.jpg
# private_dataset_new\scc_h\j esbd20x35.jpg
# private_dataset_new\scc_h\j esbd20x35.jpg
# private_dataset_new\scc_h\j esbd20x35.jpg
# private_dataset_new\scc_h\j esbd20x35.jpg
# private_dataset_new\scc_h\j esbd20x36.jpg
# private_dataset_new\scc_h\j esbd20x36.jpg
# private_dataset_new\scc_h\j esbd20x36.jpg
# private_dataset_new\scc_h\j esbd20x36.jpg
# private_dataset_new\scc_h\j esbd20x37.jpg
# private_dataset_new\scc_h\j esbd20x37.jpg
# private_dataset_new\scc_h\j esbd20x37.jpg
# private_dataset_new\scc_h\j esbd20x37.jpg
# private_dataset_new\scc_h\j esbd20x38.jpg
# private_dataset_new\scc_h\j esbd20x38.jpg
# private_dataset_new\scc_h\j esbd20x38.jpg
# private_dataset_new\scc_h\j esbd20x38.jpg
# private_dataset_new\scc_h\j esbd20x39.jpg
# private_dataset_new\scc_h\j esbd20x39.jpg
# private_dataset_new\scc_h\j esbd20x39.jpg
# private_dataset_new\scc_h\j esbd20x39.jpg
# private_dataset_new\scc_h\j esbd20x40.jpg
# private_dataset_new\scc_h\j esbd20x40.jpg
# private_dataset_new\scc_h\j esbd20x40.jpg
# private_dataset_new\scc_h\j esbd20x40.jpg
# private_dataset_new\scc_h\j esbd20x41.jpg
# private_dataset_new\scc_h\j esbd20x41.jpg
# private_dataset_new\scc_h\j esbd20x41.jpg
# private_dataset_new\scc_h\j esbd20x41.jpg
# private_dataset_new\scc_h\j esbd20x42.jpg
# private_dataset_new\scc_h\j esbd20x42.jpg
# private_dataset_new\scc_h\j esbd20x42.jpg
# private_dataset_new\scc_h\j esbd20x42.jpg
# private_dataset_new\scc_h\j esbd20x43.jpg
# private_dataset_new\scc_h\j esbd20x43.jpg
# private_dataset_new\scc_h\j esbd20x43.jpg
# private_dataset_new\scc_h\j esbd20x43.jpg
# private_dataset_new\scc_h\j esbd20x44.jpg
# private_dataset_new\scc_h\j esbd20x44.jpg
# private_dataset_new\scc_h\j esbd20x44.jpg
# private_dataset_new\scc_h\j esbd20x44.jpg
# private_dataset_new\scc_h\j esbd20x45.jpg
# private_dataset_new\scc_h\j esbd20x45.jpg
# private_dataset_new\scc_h\j esbd20x45.jpg
# private_dataset_new\scc_h\j esbd20x45.jpg
# private_dataset_new\scc_h\j esbd20x46.jpg
# private_dataset_new\scc_h\j esbd20x46.jpg
# private_dataset_new\scc_h\j esbd20x46.jpg
# private_dataset_new\scc_h\j esbd20x46.jpg
# private_dataset_new\scc_h\j esbd20x47.jpg
# private_dataset_new\scc_h\j esbd20x47.jpg
# private_dataset_new\scc_h\j esbd20x47.jpg
# private_dataset_new\scc_h\j esbd20x47.jpg
# private_dataset_new\scc_h\j esbd20x49.jpg
# private_dataset_new\scc_h\j esbd20x49.jpg
# private_dataset_new\scc_h\j esbd20x49.jpg
# private_dataset_new\scc_h\j esbd20x49.jpg
# private_dataset_new\scc_h\j esbd20x50.jpg
# private_dataset_new\scc_h\j esbd20x50.jpg
# private_dataset_new\scc_h\j esbd20x50.jpg
# private_dataset_new\scc_h\j esbd20x50.jpg
# private_dataset_new\scc_h\j esbd40x 31.jpg
# private_dataset_new\scc_h\j esbd40x 31.jpg
# private_dataset_new\scc_h\j esbd40x 31.jpg
# private_dataset_new\scc_h\j esbd40x 31.jpg
# private_dataset_new\scc_h\j esbd40x10.jpg
# private_dataset_new\scc_h\j esbd40x10.jpg
# private_dataset_new\scc_h\j esbd40x10.jpg
# private_dataset_new\scc_h\j esbd40x10.jpg
# private_dataset_new\scc_h\j esbd40x27.jpg
# private_dataset_new\scc_h\j esbd40x27.jpg
# private_dataset_new\scc_h\j esbd40x27.jpg
# private_dataset_new\scc_h\j esbd40x27.jpg
# private_dataset_new\scc_h\j esbd40x28.jpg
# private_dataset_new\scc_h\j esbd40x28.jpg
# private_dataset_new\scc_h\j esbd40x28.jpg
# private_dataset_new\scc_h\j esbd40x28.jpg
# private_dataset_new\scc_h\j esbd40x29.jpg
# private_dataset_new\scc_h\j esbd40x29.jpg
# private_dataset_new\scc_h\j esbd40x29.jpg
# private_dataset_new\scc_h\j esbd40x29.jpg
# private_dataset_new\scc_h\j esbd40x30.jpg
# private_dataset_new\scc_h\j esbd40x30.jpg
# private_dataset_new\scc_h\j esbd40x30.jpg
# private_dataset_new\scc_h\j esbd40x30.jpg
# private_dataset_new\scc_h\j esbd40x32.jpg
# private_dataset_new\scc_h\j esbd40x32.jpg
# private_dataset_new\scc_h\j esbd40x32.jpg
# private_dataset_new\scc_h\j esbd40x32.jpg
# private_dataset_new\scc_h\j esbd40x33.jpg
# private_dataset_new\scc_h\j esbd40x33.jpg
# private_dataset_new\scc_h\j esbd40x33.jpg
# private_dataset_new\scc_h\j esbd40x33.jpg
# private_dataset_new\scc_h\j esbd40x34.jpg
# private_dataset_new\scc_h\j esbd40x34.jpg
# private_dataset_new\scc_h\j esbd40x34.jpg
# private_dataset_new\scc_h\j esbd40x34.jpg
# private_dataset_new\scc_h\j esbd40x35.jpg
# private_dataset_new\scc_h\j esbd40x35.jpg
# private_dataset_new\scc_h\j esdb 20x 34.jpg
# private_dataset_new\scc_h\j esdb 20x 34.jpg
# private_dataset_new\scc_h\j esdb 20x 34.jpg
# private_dataset_new\scc_h\j esdb 20x 34.jpg
# private_dataset_new\scc_h\j esmd 20x 1.jpg
# private_dataset_new\scc_h\j esmd 20x 1.jpg
# private_dataset_new\scc_h\j esmd 20x 1.jpg
# private_dataset_new\scc_h\j esmd 20x 1.jpg
# private_dataset_new\scc_h\j esmd 20x 2.jpg
# private_dataset_new\scc_h\j esmd 20x 2.jpg
# private_dataset_new\scc_h\j esmd 20x 2.jpg
# private_dataset_new\scc_h\j esmd 20x 2.jpg
# private_dataset_new\scc_h\j esmd 20x 20.jpg
# private_dataset_new\scc_h\j esmd 20x 20.jpg
# private_dataset_new\scc_h\j esmd 20x 20.jpg
# private_dataset_new\scc_h\j esmd 20x 20.jpg
# private_dataset_new\scc_h\j esmd 20x 24.jpg
# private_dataset_new\scc_h\j esmd 20x 24.jpg
# private_dataset_new\scc_h\j esmd 20x 24.jpg
# private_dataset_new\scc_h\j esmd 20x 24.jpg
# private_dataset_new\scc_h\j esmd 20x 29.jpg
# private_dataset_new\scc_h\j esmd 20x 29.jpg
# private_dataset_new\scc_h\j esmd 20x 29.jpg
# private_dataset_new\scc_h\j esmd 20x 29.jpg
# private_dataset_new\scc_h\j esmd 20x22.jpg
# private_dataset_new\scc_h\j esmd 20x22.jpg
# private_dataset_new\scc_h\j esmd 20x22.jpg
# private_dataset_new\scc_h\j esmd 20x22.jpg
# private_dataset_new\scc_h\j esmd 20x25.jpg
# private_dataset_new\scc_h\j esmd 20x25.jpg
# private_dataset_new\scc_h\j esmd 20x25.jpg
# private_dataset_new\scc_h\j esmd 20x25.jpg
# private_dataset_new\scc_h\j esmd 20x26.jpg
# private_dataset_new\scc_h\j esmd 20x26.jpg
# private_dataset_new\scc_h\j esmd 20x26.jpg
# private_dataset_new\scc_h\j esmd 20x26.jpg
# private_dataset_new\scc_h\j esmd 20x3.jpg
# private_dataset_new\scc_h\j esmd 20x3.jpg
# private_dataset_new\scc_h\j esmd 20x3.jpg
# private_dataset_new\scc_h\j esmd 20x3.jpg
# private_dataset_new\scc_h\j esmd 20x5.jpg
# private_dataset_new\scc_h\j esmd 20x5.jpg
# private_dataset_new\scc_h\j esmd 20x5.jpg
# private_dataset_new\scc_h\j esmd 20x5.jpg
# private_dataset_new\scc_h\j esmd 20x54.jpg
# private_dataset_new\scc_h\j esmd 20x54.jpg
# private_dataset_new\scc_h\j esmd 20x54.jpg
# private_dataset_new\scc_h\j esmd 20x54.jpg
# private_dataset_new\scc_h\j esmd20x 19.jpg
# private_dataset_new\scc_h\j esmd20x 19.jpg
# private_dataset_new\scc_h\j esmd20x 19.jpg
# private_dataset_new\scc_h\j esmd20x 19.jpg
# private_dataset_new\scc_h\j esmd20x 28.jpg
# private_dataset_new\scc_h\j esmd20x 28.jpg
# private_dataset_new\scc_h\j esmd20x 28.jpg
# private_dataset_new\scc_h\j esmd20x 28.jpg
# private_dataset_new\scc_h\j esmd20x14.jpg
# private_dataset_new\scc_h\j esmd20x14.jpg
# private_dataset_new\scc_h\j esmd20x14.jpg
# private_dataset_new\scc_h\j esmd20x14.jpg
# private_dataset_new\scc_h\j esmd20x23.jpg
# private_dataset_new\scc_h\j esmd20x23.jpg
# private_dataset_new\scc_h\j esmd20x23.jpg
# private_dataset_new\scc_h\j esmd20x23.jpg
# private_dataset_new\scc_h\j esmd20x30.jpg
# private_dataset_new\scc_h\j esmd20x30.jpg
# private_dataset_new\scc_h\j esmd20x30.jpg
# private_dataset_new\scc_h\j esmd20x30.jpg
# private_dataset_new\scc_h\j esmd20x4.jpg
# private_dataset_new\scc_h\j esmd20x4.jpg
# private_dataset_new\scc_h\j esmd20x4.jpg
# private_dataset_new\scc_h\j esmd20x4.jpg
# private_dataset_new\scc_h\j esmd20x52.jpg
# private_dataset_new\scc_h\j esmd20x52.jpg
# private_dataset_new\scc_h\j esmd20x52.jpg
# private_dataset_new\scc_h\j esmd20x52.jpg
# private_dataset_new\scc_h\j esmd20x53.jpg
# private_dataset_new\scc_h\j esmd20x53.jpg
# private_dataset_new\scc_h\j esmd20x53.jpg
# private_dataset_new\scc_h\j esmd20x53.jpg
# private_dataset_new\scc_h\j esmd20x6.jpg
# private_dataset_new\scc_h\j esmd20x6.jpg
# private_dataset_new\scc_h\j esmd20x6.jpg
# private_dataset_new\scc_h\j esmd20x6.jpg
# private_dataset_new\scc_h\j esmd40x 19.jpg
# private_dataset_new\scc_h\j esmd40x 19.jpg
# private_dataset_new\scc_h\j esmd40x 19.jpg
# private_dataset_new\scc_h\j esmd40x 19.jpg
# private_dataset_new\scc_h\j esmd40x11.jpg
# private_dataset_new\scc_h\j esmd40x11.jpg
# private_dataset_new\scc_h\j esmd40x11.jpg
# private_dataset_new\scc_h\j esmd40x11.jpg
# private_dataset_new\scc_h\j esmd40x12.jpg
# private_dataset_new\scc_h\j esmd40x12.jpg
# private_dataset_new\scc_h\j esmd40x12.jpg
# private_dataset_new\scc_h\j esmd40x12.jpg
# private_dataset_new\scc_h\j esmd40x13.jpg
# private_dataset_new\scc_h\j esmd40x13.jpg
# private_dataset_new\scc_h\j esmd40x13.jpg
# private_dataset_new\scc_h\j esmd40x13.jpg
# private_dataset_new\scc_h\j esmd40x2.jpg
# private_dataset_new\scc_h\j esmd40x2.jpg
# private_dataset_new\scc_h\j esmd40x2.jpg
# private_dataset_new\scc_h\j esmd40x2.jpg
# private_dataset_new\scc_h\j esmd40x20.jpg
# private_dataset_new\scc_h\j esmd40x20.jpg
# private_dataset_new\scc_h\j esmd40x20.jpg
# private_dataset_new\scc_h\j esmd40x20.jpg
# private_dataset_new\scc_h\j esmd40x3.jpg
# private_dataset_new\scc_h\j esmd40x3.jpg
# private_dataset_new\scc_h\j esmd40x3.jpg
# private_dataset_new\scc_h\j esmd40x3.jpg
# private_dataset_new\scc_h\j esmd40x4.jpg
# private_dataset_new\scc_h\j esmd40x4.jpg
# private_dataset_new\scc_h\j esmd40x4.jpg
# private_dataset_new\scc_h\j esmd40x4.jpg
# private_dataset_new\scc_h\j esmd40x5.jpg
# private_dataset_new\scc_h\j esmd40x5.jpg
# private_dataset_new\scc_h\j esmd40x5.jpg
# private_dataset_new\scc_h\j esmd40x5.jpg
# private_dataset_new\scc_h\j esmd40x51.jpg
# private_dataset_new\scc_h\j esmd40x51.jpg
# private_dataset_new\scc_h\j esmd40x51.jpg
# private_dataset_new\scc_h\j esmd40x51.jpg
# private_dataset_new\scc_h\j esmd40x52.jpg
# private_dataset_new\scc_h\j esmd40x52.jpg
# private_dataset_new\scc_h\j esmd40x52.jpg
# private_dataset_new\scc_h\j esmd40x52.jpg
# private_dataset_new\scc_h\j esmd40x53.jpg
# private_dataset_new\scc_h\j esmd40x53.jpg
# private_dataset_new\scc_h\j esmd40x53.jpg
# private_dataset_new\scc_h\j esmd40x53.jpg
# private_dataset_new\scc_h\j esmd40x54.jpg
# private_dataset_new\scc_h\j esmd40x54.jpg
# private_dataset_new\scc_h\j esmd40x54.jpg
# private_dataset_new\scc_h\j esmd40x54.jpg
# private_dataset_new\scc_h\j esmd40x55.jpg
# private_dataset_new\scc_h\j esmd40x55.jpg
# private_dataset_new\scc_h\j esmd40x55.jpg
# private_dataset_new\scc_h\j esmd40x55.jpg
# private_dataset_new\scc_h\j esmd40x6.jpg
# private_dataset_new\scc_h\j esmd40x6.jpg
# private_dataset_new\scc_h\j esmd40x6.jpg
# private_dataset_new\scc_h\j esmd40x6.jpg
# private_dataset_new\scc_h\j espd 20x 16.jpg
# private_dataset_new\scc_h\j espd 20x 16.jpg
# private_dataset_new\scc_h\j espd 20x 16.jpg
# private_dataset_new\scc_h\j espd 20x 16.jpg
# private_dataset_new\scc_h\j espd 20x 9.jpg
# private_dataset_new\scc_h\j espd 20x 9.jpg
# private_dataset_new\scc_h\j espd 20x 9.jpg
# private_dataset_new\scc_h\j espd 20x 9.jpg
# private_dataset_new\scc_h\j espd 20x12.jpg
# private_dataset_new\scc_h\j espd 20x12.jpg
# private_dataset_new\scc_h\j espd 20x12.jpg
# private_dataset_new\scc_h\j espd 20x12.jpg
# private_dataset_new\scc_h\j espd 20x18.jpg
# private_dataset_new\scc_h\j espd 20x18.jpg
# private_dataset_new\scc_h\j espd 20x18.jpg
# private_dataset_new\scc_h\j espd 20x18.jpg
# private_dataset_new\scc_h\j espd 20x21.jpg
# private_dataset_new\scc_h\j espd 20x21.jpg
# private_dataset_new\scc_h\j espd 20x21.jpg
# private_dataset_new\scc_h\j espd 20x21.jpg
# private_dataset_new\scc_h\j espd 40x8.jpg
# private_dataset_new\scc_h\j espd 40x8.jpg
# private_dataset_new\scc_h\j espd 40x8.jpg
# private_dataset_new\scc_h\j espd 40x8.jpg
# private_dataset_new\scc_h\j espd20x 11.jpg
# private_dataset_new\scc_h\j espd20x 11.jpg
# private_dataset_new\scc_h\j espd20x 11.jpg
# private_dataset_new\scc_h\j espd20x 11.jpg
# private_dataset_new\scc_h\j espd20x 15.jpg
# private_dataset_new\scc_h\j espd40x21.jpg
# private_dataset_new\scc_h\j espd40x21.jpg
# private_dataset_new\scc_h\j espd40x22.jpg
# private_dataset_new\scc_h\j espd40x22.jpg
# private_dataset_new\scc_h\j espd40x22.jpg
# private_dataset_new\scc_h\j espd40x22.jpg
# private_dataset_new\scc_h\j espd40x23.jpg
# private_dataset_new\scc_h\j espd40x23.jpg
# private_dataset_new\scc_h\j espd40x23.jpg
# private_dataset_new\scc_h\j espd40x23.jpg
# private_dataset_new\scc_h\j espd40x24.jpg
# private_dataset_new\scc_h\j espd40x24.jpg
# private_dataset_new\scc_h\j espd40x24.jpg
# private_dataset_new\scc_h\j espd40x24.jpg
# private_dataset_new\scc_h\j espd40x25.jpg
# private_dataset_new\scc_h\j espd40x25.jpg
# private_dataset_new\scc_h\j espd40x25.jpg
# private_dataset_new\scc_h\j espd40x25.jpg
# private_dataset_new\scc_h\j espd40x26.jpg
# private_dataset_new\scc_h\j espd40x26.jpg
# private_dataset_new\scc_h\j espd40x26.jpg
# private_dataset_new\scc_h\j espd40x26.jpg
# private_dataset_new\scc_h\j espd40x7.jpg
# private_dataset_new\scc_h\j espd40x7.jpg
# private_dataset_new\scc_h\j espd40x7.jpg
# private_dataset_new\scc_h\j espd40x7.jpg
# private_dataset_new\scc_h\j espd40x9.jpg
# private_dataset_new\scc_h\j espd40x9.jpg
# private_dataset_new\scc_h\j espd40x9.jpg
# private_dataset_new\scc_h\j espd40x9.jpg
# private_dataset_new\scc_h\jemd20x6.jpg
# private_dataset_new\scc_h\jemd20x6.jpg
# private_dataset_new\scc_h\jemd20x6.jpg
# private_dataset_new\scc_h\jemd20x6.jpg
# private_dataset_new\scc_h\jepd20x2.jpg
# private_dataset_new\scc_h\jepd20x2.jpg
# private_dataset_new\scc_h\jepd20x2.jpg
# private_dataset_new\scc_h\jepd20x2.jpg
# private_dataset_new\scc_h\jepd20x3.jpg
# private_dataset_new\scc_h\jepd20x3.jpg
# private_dataset_new\scc_h\jepd20x3.jpg
# private_dataset_new\scc_h\jepd20x3.jpg
# private_dataset_new\scc_h\jepd20x7.jpg
# private_dataset_new\scc_h\jepd20x7.jpg
# private_dataset_new\scc_h\jepd20x7.jpg
# private_dataset_new\scc_h\jepd20x7.jpg

# %%
def rename_files(folder_path):
    for root, dirs, files in os.walk(folder_path):
        for filename in files:
            if filename.endswith('.jpg'):
                old_name = os.path.join(root, filename)
                new_name = os.path.join(root, filename.replace('.jpg', '', 1))
                os.rename(old_name, new_name)

# Replace 'folder_path' with the path to your main folder
folder_path = 'private_dataset_new'
rename_files(folder_path)

# %%
def rename_files(folder_path):
    for root, dirs, files in os.walk(folder_path):
        for filename in files:
            old_name = os.path.join(root, filename)
            new_name = os.path.join(root, filename[1:])
            os.rename(old_name, new_name)

# Replace 'folder_path' with the path to your main folder
folder_path = 'private_dataset_new'
rename_files(folder_path)

# %%
def rename_files(folder_path):
    for root, dirs, files in os.walk(folder_path):
        for filename in files:
            if filename.startswith(' '):
                old_name = os.path.join(root, filename)
                new_name = os.path.join(root, filename.lstrip())
                if os.path.exists(new_name):
                    os.remove(new_name)
                os.rename(old_name, new_name)

# Replace 'folder_path' with the path to your main folder
folder_path = 'private_dataset_new'
rename_files(folder_path)

# %%
def rename_files(folder_path):
    for filename in os.listdir(folder_path):
        # Get the full path of the file
        file_path = os.path.join(folder_path, filename)

        # Check if the path represents a file (not a directory)
        if os.path.isfile(file_path):
            # Extract the new filename with the first character replaced
            new_filename = "aca_" + filename[1:]

            # Construct the new path with the renamed file
            new_file_path = os.path.join(folder_path, new_filename)

            # Rename the file
            os.rename(file_path, new_file_path)

# Specify the path to the folder containing the files
folder_path = 'new_private_dataset/aca_h'

# Call the function to rename the files
rename_files(folder_path)

# %%
def rename_files(folder_path):
    for filename in os.listdir(folder_path):
        # Get the full path of the file
        file_path = os.path.join(folder_path, filename)

        # Check if the path represents a file (not a directory)
        if os.path.isfile(file_path):
            # Extract the new filename with the first character replaced
            new_filename = "nor_" + filename[1:]

            # Construct the new path with the renamed file
            new_file_path = os.path.join(folder_path, new_filename)

            # Rename the file
            os.rename(file_path, new_file_path)

# Specify the path to the folder containing the files
folder_path = 'new_private_dataset/nor_h'

# Call the function to rename the files
rename_files(folder_path)

# %%
import os

def rename_files(folder_path):
    for root, _, files in os.walk(folder_path):
        for filename in files:
            # Get the full path of the file
            file_path = os.path.join(root, filename)

            # Check if the path represents a file (not a directory)
            if os.path.isfile(file_path):
                # Split the filename into base name and extension
                base_name, extension = os.path.splitext(filename)

                # Add an underscore four characters before the extension
                if len(base_name) > 4:
                    new_base_name = base_name[:-3] + '_' + base_name[-3:]
                else:
                    new_base_name = '_' + base_name

                # Construct the new filename
                new_filename = new_base_name + extension

                # Construct the new path with the renamed file
                new_file_path = os.path.join(root, new_filename)

                # Rename the file
                os.rename(file_path, new_file_path)

# Specify the path to the main folder containing the subfolders and files
folder_path = 'new_private_dataset'

# Call the function to rename the files
rename_files(folder_path)

# %%
def rename_files(folder_path):
    for root, _, files in os.walk(folder_path):
        for filename in files:
            # Get the full path of the file
            file_path = os.path.join(root, filename)

            # Check if the path represents a file (not a directory)
            if os.path.isfile(file_path):
                # Convert the filename to lowercase
                new_filename = filename.lower()

                # Construct the new path with the renamed file
                new_file_path = os.path.join(root, new_filename)

                # Rename the file
                os.rename(file_path, new_file_path)

# Specify the path to the main folder containing the subfolders and files
folder_path = 'private_dataset'

# Call the function to rename the files
rename_files(folder_path)

# %%
def rename_files(folder_path):
    for root, _, files in os.walk(folder_path):
        for filename in files:
            # Get the full path of the file
            file_path = os.path.join(root, filename)

            # Check if the path represents a file (not a directory)
            if os.path.isfile(file_path):
                # Split the filename into base name and extension
                base_name, extension = os.path.splitext(filename)

                # Add underscore before and after '20x' and '40x'
                new_base_name = base_name.replace('__', '_')
                # Construct the new filename
                new_filename = new_base_name + extension

                # Construct the new path with the renamed file
                new_file_path = os.path.join(root, new_filename)

                # Rename the file
                os.rename(file_path, new_file_path)

# Specify the path to the main folder containing the subfolders and files
folder_path = 'new_private_dataset_prefinal'

# Call the function to rename the files
rename_files(folder_path)

# %%
def rename_files(folder_path):
    for root, _, files in os.walk(folder_path):
        for filename in files:
            # Get the full path of the file
            file_path = os.path.join(root, filename)

            # Check if the path represents a file (not a directory)
            if os.path.isfile(file_path):
                # Remove spaces from the filename
                new_filename = filename.replace('__', '_')

                # Construct the new path with the renamed file
                new_file_path = os.path.join(root, new_filename)

                # Rename the file
                os.rename(file_path, new_file_path)

# Specify the path to the main folder containing the subfolders and files
folder_path = 'new_private_dataset'
# Call the function to rename the files
rename_files(folder_path)

# %%
# Iterate over the files in the folder
for filename in os.listdir(folder_path):
            
        old_name = os.path.join(folder_path, filename)

              
        parts = filename.split('_')
        
        parte3 = parts[3].split('.')

        # Rearrange the parts to the new format
        new_name = f"{parts[0]}_{parts[1]}_{parte3[0]}_{parts[2]}{'.jpg'}"

       
        new_name = os.path.join(folder_path, new_name)
        print(new_name)
        # Rename the file
        os.rename(old_name, new_name)
# Out:
# private_dataset/scc_h\scc_h_40X_100.jpg
# private_dataset/scc_h\scc_h_40X_101.jpg
# private_dataset/scc_h\scc_h_40X_102.jpg
# private_dataset/scc_h\scc_h_20X_103.jpg
# private_dataset/scc_h\scc_h_20X_104.jpg
# private_dataset/scc_h\scc_h_20X_105.jpg
# private_dataset/scc_h\scc_h_20X_106.jpg
# private_dataset/scc_h\scc_h_20X_107.jpg
# private_dataset/scc_h\scc_h_20X_108.jpg
# private_dataset/scc_h\scc_h_20X_109.jpg
# private_dataset/scc_h\scc_h_20X_10.jpg
# private_dataset/scc_h\scc_h_20X_110.jpg
# private_dataset/scc_h\scc_h_40X_111.jpg
# private_dataset/scc_h\scc_h_40X_112.jpg
# private_dataset/scc_h\scc_h_40X_113.jpg
# private_dataset/scc_h\scc_h_40X_114.jpg
# private_dataset/scc_h\scc_h_40X_115.jpg
# private_dataset/scc_h\scc_h_40X_116.jpg
# private_dataset/scc_h\scc_h_20X_117.jpg
# private_dataset/scc_h\scc_h_20X_119.jpg
# private_dataset/scc_h\scc_h_20X_11.jpg
# private_dataset/scc_h\scc_h_20X_120.jpg
# private_dataset/scc_h\scc_h_40X_121.jpg
# private_dataset/scc_h\scc_h_40X_122.jpg
# private_dataset/scc_h\scc_h_40X_123.jpg
# private_dataset/scc_h\scc_h_40X_124.jpg
# private_dataset/scc_h\scc_h_20X_125.jpg
# private_dataset/scc_h\scc_h_20X_126.jpg
# private_dataset/scc_h\scc_h_20X_128.jpg
# private_dataset/scc_h\scc_h_40X_129.jpg
# private_dataset/scc_h\scc_h_20X_12.jpg
# private_dataset/scc_h\scc_h_40X_130.jpg
# private_dataset/scc_h\scc_h_40X_131.jpg
# private_dataset/scc_h\scc_h_40X_132.jpg
# private_dataset/scc_h\scc_h_40X_133.jpg
# private_dataset/scc_h\scc_h_40X_134.jpg
# private_dataset/scc_h\scc_h_40X_135.jpg
# private_dataset/scc_h\scc_h_40X_136.jpg
# private_dataset/scc_h\scc_h_20X_137.jpg
# private_dataset/scc_h\scc_h_20X_138.jpg
# private_dataset/scc_h\scc_h_20X_139.jpg
# private_dataset/scc_h\scc_h_20X_13.jpg
# private_dataset/scc_h\scc_h_20X_140.jpg
# private_dataset/scc_h\scc_h_40X_141.jpg
# private_dataset/scc_h\scc_h_40X_143.jpg
# private_dataset/scc_h\scc_h_40X_144.jpg
# private_dataset/scc_h\scc_h_20X_145.jpg
# private_dataset/scc_h\scc_h_20X_146.jpg
# private_dataset/scc_h\scc_h_20X_147.jpg
# private_dataset/scc_h\scc_h_20X_148.jpg
# private_dataset/scc_h\scc_h_40X_149.jpg
# private_dataset/scc_h\scc_h_20X_14.jpg
# private_dataset/scc_h\scc_h_40X_529.jpg
# private_dataset/scc_h\scc_h_20X_52.jpg
# private_dataset/scc_h\scc_h_40X_530.jpg
# private_dataset/scc_h\scc_h_40X_531.jpg
# private_dataset/scc_h\scc_h_40X_532.jpg
# private_dataset/scc_h\scc_h_20X_533.jpg
# private_dataset/scc_h\scc_h_20X_534.jpg
# private_dataset/scc_h\scc_h_20X_535.jpg
# private_dataset/scc_h\scc_h_20X_536.jpg
# private_dataset/scc_h\scc_h_20X_537.jpg
# private_dataset/scc_h\scc_h_20X_538.jpg
# private_dataset/scc_h\scc_h_20X_539.jpg
# private_dataset/scc_h\scc_h_40X_53.jpg
# private_dataset/scc_h\scc_h_20X_540.jpg
# private_dataset/scc_h\scc_h_20X_541.jpg
# private_dataset/scc_h\scc_h_20X_542.jpg
# private_dataset/scc_h\scc_h_20X_543.jpg
# private_dataset/scc_h\scc_h_20X_544.jpg
# private_dataset/scc_h\scc_h_20X_545.jpg
# private_dataset/scc_h\scc_h_20X_546.jpg
# private_dataset/scc_h\scc_h_20X_547.jpg
# private_dataset/scc_h\scc_h_20X_548.jpg
# private_dataset/scc_h\scc_h_20X_549.jpg
# private_dataset/scc_h\scc_h_40X_54.jpg
# private_dataset/scc_h\scc_h_20X_550.jpg
# private_dataset/scc_h\scc_h_20X_551.jpg
# private_dataset/scc_h\scc_h_20X_552.jpg
# private_dataset/scc_h\scc_h_20X_553.jpg
# private_dataset/scc_h\scc_h_20X_554.jpg
# private_dataset/scc_h\scc_h_20X_555.jpg
# private_dataset/scc_h\scc_h_20X_556.jpg
# private_dataset/scc_h\scc_h_20X_557.jpg
# private_dataset/scc_h\scc_h_20X_558.jpg
# private_dataset/scc_h\scc_h_20X_559.jpg
# private_dataset/scc_h\scc_h_40X_55.jpg
# private_dataset/scc_h\scc_h_20X_560.jpg
# private_dataset/scc_h\scc_h_40X_561.jpg
# private_dataset/scc_h\scc_h_40X_562.jpg
# private_dataset/scc_h\scc_h_40X_563.jpg
# private_dataset/scc_h\scc_h_40X_564.jpg
# private_dataset/scc_h\scc_h_40X_565.jpg
# private_dataset/scc_h\scc_h_40X_566.jpg
# private_dataset/scc_h\scc_h_40X_567.jpg
# private_dataset/scc_h\scc_h_40X_568.jpg
# private_dataset/scc_h\scc_h_40X_569.jpg
# private_dataset/scc_h\scc_h_40X_56.jpg
# private_dataset/scc_h\scc_h_40X_570.jpg
# private_dataset/scc_h\scc_h_40X_571.jpg
# private_dataset/scc_h\scc_h_40X_572.jpg
# private_dataset/scc_h\scc_h_40X_573.jpg
# private_dataset/scc_h\scc_h_40X_574.jpg
# private_dataset/scc_h\scc_h_40X_575.jpg
# private_dataset/scc_h\scc_h_40X_576.jpg
# private_dataset/scc_h\scc_h_40X_577.jpg
# private_dataset/scc_h\scc_h_40X_578.jpg
# private_dataset/scc_h\scc_h_40X_579.jpg
# private_dataset/scc_h\scc_h_20X_57.jpg
# private_dataset/scc_h\scc_h_40X_580.jpg
# private_dataset/scc_h\scc_h_40X_581.jpg
# private_dataset/scc_h\scc_h_40X_582.jpg
# private_dataset/scc_h\scc_h_40X_583.jpg
# private_dataset/scc_h\scc_h_40X_584.jpg
# private_dataset/scc_h\scc_h_40X_585.jpg
# private_dataset/scc_h\scc_h_40X_586.jpg
# private_dataset/scc_h\scc_h_40X_587.jpg
# private_dataset/scc_h\scc_h_40X_588.jpg
# private_dataset/scc_h\scc_h_40X_589.jpg
# private_dataset/scc_h\scc_h_20X_58.jpg
# private_dataset/scc_h\scc_h_40X_590.jpg
# private_dataset/scc_h\scc_h_40X_591.jpg
# private_dataset/scc_h\scc_h_40X_592.jpg
# private_dataset/scc_h\scc_h_20X_59.jpg
# private_dataset/scc_h\scc_h_40X_5.jpg
# private_dataset/scc_h\scc_h_20X_60.jpg
# private_dataset/scc_h\scc_h_40X_61.jpg
# private_dataset/scc_h\scc_h_40X_62.jpg
# private_dataset/scc_h\scc_h_40X_63.jpg
# private_dataset/scc_h\scc_h_40X_64.jpg
# private_dataset/scc_h\scc_h_20X_65.jpg
# private_dataset/scc_h\scc_h_20X_66.jpg
# private_dataset/scc_h\scc_h_20X_67.jpg
# private_dataset/scc_h\scc_h_20X_68.jpg
# private_dataset/scc_h\scc_h_40X_69.jpg
# private_dataset/scc_h\scc_h_40X_6.jpg
# private_dataset/scc_h\scc_h_40X_70.jpg
# private_dataset/scc_h\scc_h_40X_71.jpg
# private_dataset/scc_h\scc_h_40X_72.jpg
# private_dataset/scc_h\scc_h_40X_73.jpg
# private_dataset/scc_h\scc_h_40X_74.jpg
# private_dataset/scc_h\scc_h_40X_75.jpg
# private_dataset/scc_h\scc_h_40X_76.jpg
# private_dataset/scc_h\scc_h_20X_77.jpg
# private_dataset/scc_h\scc_h_20X_78.jpg
# private_dataset/scc_h\scc_h_20X_79.jpg
# private_dataset/scc_h\scc_h_20X_80.jpg
# private_dataset/scc_h\scc_h_40X_81.jpg
# private_dataset/scc_h\scc_h_40X_82.jpg
# private_dataset/scc_h\scc_h_40X_83.jpg
# private_dataset/scc_h\scc_h_20X_84.jpg
# private_dataset/scc_h\scc_h_20X_85.jpg
# private_dataset/scc_h\scc_h_20X_86.jpg
# private_dataset/scc_h\scc_h_20X_87.jpg
# private_dataset/scc_h\scc_h_40X_88.jpg
# private_dataset/scc_h\scc_h_40X_89.jpg
# private_dataset/scc_h\scc_h_40X_8.jpg
# private_dataset/scc_h\scc_h_40X_90.jpg
# private_dataset/scc_h\scc_h_40X_91.jpg
# private_dataset/scc_h\scc_h_20X_92.jpg
# private_dataset/scc_h\scc_h_20X_93.jpg
# private_dataset/scc_h\scc_h_20X_94.jpg
# private_dataset/scc_h\scc_h_20X_95.jpg
# private_dataset/scc_h\scc_h_20X_96.jpg
# private_dataset/scc_h\scc_h_20X_97.jpg
# private_dataset/scc_h\scc_h_20X_98.jpg
# private_dataset/scc_h\scc_h_20X_99.jpg
# private_dataset/scc_h\scc_h_20X_9.jpg

# %%
folder_path = 'private_dataset/scc_h'  # Specify the folder path
